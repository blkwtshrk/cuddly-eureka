# %% [markdown]
# ### Условия

# %%
user_input = str(input ('number of times your ass was racked: '))

if user_input == 'one':
    print('1')

elif user_input == 'two':
    print('2')

else:
    print('your ass is ruined')
# Out:
# your ass is ruined

# %%
user_input = input ('number of times your ass was racked: ')

if user_input.isnumeric():
    user_input = int(user_input)
    if user_input == 1:
        print('one time is not gay')
    elif user_input == 2:
        print('two times is semigay')
    else:
        print('your ass is ruined. you are 3.14ass')

else:
    print('Enter a number you, piece of shit')
# Out:
# your ass is ruined. you are 3.14ass

# %%
names = ['John', 'Snow', 'James', 'Bob', 'Bill', 'Jim']

for name in names:
    if name.startswith('J'):
        print(name)
# Out:
# John
# James
# Jim

# %%
names = ['John', 'Snow', 'James', 'Bob', 'Bill', 'Jim']

for name in names:
    if name.startswith('J'):
       print('Mr.', end='\n')
# Out:
# Mr.
# Mr.
# Mr.

# %%
people = {'John': 132, 'Tom': 167, 'James': 234}

for person in people:
    print(person)
# Out:
# {'John'}
# {'Tom'}
# {'James'}

# %%
people = {'John': 132, 'Tom': 167, 'James': 234}

#for person, height in people.items():
    #print(f"{person}: {height}")

for person in people:
    print(f"{person}: {people[person]}")
# Out:
# John: 132
# Tom: 167
# James: 234

# %%
text = 'You dare step into my domain? Then you’ll learn exactly what it means to be hunted.'

words = text.split()
fin_words = []
for word in words:
    if 'o' in word:
        print(word)
    else:
        fin_words.append(word)

print(' '.join(fin_words))
# Out:
# You
# into
# domain?
# you’ll
# to
# dare step my Then learn exactly what it means be hunted.
