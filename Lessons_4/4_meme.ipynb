# %%
text = 'i love abort'
print ('abort' in text)
# Out:
# True

# %%
text = "i love abort because abort is handy"

happiness = "abort"

count = text.count(happiness)

print("Text:", text)
print("the world gets", happiness, count, "times")
# Out:
# Text: i love abort because abort is handy
# the world gets abort 2 times

# %%
jira = []
jira.append("iluha_demon")
print(jira)
# Out:
# ['iluha_demon']

# %%
queue = []
queue.append("send_email")
queue.append("generate_report")

task = queue.pop(0)
print(queue)
# Out:
# ['generate_report']

# %%
# пустой кортеж:
empty = ()

# кортеж с числами:
numbers = (1, 2, 3, 4)

# кортеж с разными типами:
person = ("Mother", 42, True, "abort")
print(person.count("abort"))
# Out:
# 1

# %%
guests = set()

# зовем на тусу
guests.add("ethan")         # гг
guests.add("chris")         # чел который вечно меняет внешку
guests.add("ethan")         # опять пришел в гости? иди на хуй, дубликаты не нужны
guests.add("karl")          # неверный брат-металлолом

print("guests in lady dimitrescu's castle:")
for guest in guests:
    print(f"loser {guest}")

if "ethan" in guests:
    print("ethhan has dared to enter the castle... ")
    

guests.remove("ethan")
for guest in guests:
    print(f"left {guest}")
# Out:
# guests in lady dimitrescu's castle:
# loser ethan
# loser karl
# loser chris
# ethhan has dared to enter the castle...
# left karl
# left chris

# %%
bosses = {
    "Троянов": "Выдает зп",
    "Путанов": "Выдает шлюх",
    "Лизанов": "Выдает куни",
    "Анналов": "Выдает колы",
}
print("Боссы ЛСД:")
for boss, profession in bosses.items():
    print(f"{boss} - профессия: {profession}")

if "Троянов" in bosses:
    print("\nТроя готова к т-вирусам!")
# Out:
# Боссы ЛСД:
# Троянов - профессия: Выдает зп
# Путанов - профессия: Выдает шлюх
# Лизанов - профессия: Выдает куни
# Анналов - профессия: Выдает колы
#
# Троя готова к т-вирусам!

# %% [markdown]
# на всякий

# %%
123
